# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None)
import time
import numpy as np

# %%
test_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season=2021-22&SeasonType=Regular%20Season&StatCategory=PTS'

# %%
r = requests.get(url=test_url).json()

# %%
table_headers = r['resultSet']['headers']

# %%
pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
# Out:
#      PLAYER_ID  RANK                 PLAYER     TEAM_ID TEAM  GP   MIN   FGM  \
# 0       203954     1            Joel Embiid  1610612755  PHI  68  33.8   9.8
# 1       203507     2  Giannis Antetokounmpo  1610612749  MIL  67  32.9  10.3
# 2      1629029     3            Luka Doncic  1610612742  DAL  65  35.4   9.9
# 3      1629027     4             Trae Young  1610612737  ATL  76  34.9   9.4
# 4       201942     5          DeMar DeRozan  1610612741  CHI  76  36.1  10.2
# ..         ...   ...                    ...         ...  ...  ..   ...   ...
# 223    1628373   224        Frank Ntilikina  1610612742  DAL  58  11.8   1.5
# 224    1629308   225  Juan Toscano-Anderson  1610612744  GSW  73  13.6   1.6
# 225    1629162   226      Jordan McLaughlin  1610612750  MIN  62  14.5   1.4
# 226    1630235   227          Trent Forrest  1610612762  UTA  60  12.8   1.3
# 227    1630625   228          Dalano Banton  1610612761  TOR  64  10.9   1.3
#
#       FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM   FTA  FT_PCT  OREB  DREB   REB  \
# 0    19.6   0.499   1.4   3.7    0.371  9.6  11.8   0.814   2.1   9.6  11.7
# 1    18.6   0.553   1.1   3.6    0.293  8.3  11.4   0.722   2.0   9.6  11.6
# 2    21.6   0.457   3.1   8.8    0.353  5.6   7.5   0.744   0.9   8.3   9.1
# 3    20.3   0.460   3.1   8.0    0.382  6.6   7.3   0.904   0.7   3.1   3.7
# 4    20.2   0.504   0.7   1.9    0.352  6.8   7.8   0.877   0.7   4.4   5.2
# ..    ...     ...   ...   ...      ...  ...   ...     ...   ...   ...   ...
# 223   3.8   0.399   0.7   1.9    0.342  0.4   0.4   0.960   0.2   1.2   1.4
# 224   3.2   0.489   0.4   1.2    0.322  0.5   1.0   0.571   0.4   2.0   2.4
# 225   3.2   0.440   0.4   1.4    0.318  0.5   0.6   0.750   0.4   1.2   1.5
# 226   2.6   0.490   0.1   0.5    0.185  0.6   0.8   0.792   0.4   1.3   1.7
# 227   3.2   0.411   0.2   0.8    0.255  0.4   0.7   0.591   0.6   1.3   1.9
#
#      AST  STL  BLK  TOV   PTS   EFF
# 0    4.2  1.1  1.5  3.1  30.6  33.9
# 1    5.8  1.1  1.4  3.3  29.9  35.0
# 2    8.7  1.2  0.6  4.5  28.4  29.8
# 3    9.7  0.9  0.1  4.0  28.4  27.2
# 4    4.9  0.9  0.3  2.4  27.9  25.8
# ..   ...  ...  ...  ...   ...   ...
# 223  1.2  0.5  0.1  0.5   4.1   4.4
# 224  1.7  0.7  0.2  0.9   4.1   6.1
# 225  2.9  0.9  0.2  0.6   3.8   6.7
# 226  1.8  0.5  0.1  0.8   3.3   5.0
# 227  1.5  0.4  0.2  0.8   3.2   4.3
#
# [228 rows x 25 columns]

# %%
temp_df1 = pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
temp_df2 = pd.DataFrame({'Year':['2021-22' for i in range(len(temp_df1))],
                         'Season_type':['Regular%20Season' for i in range(len(temp_df1))]})
temp_df3 = pd.concat([temp_df2,temp_df1], axis=1)
temp_df3
# Out:
#         Year       Season_type  PLAYER_ID  RANK                 PLAYER  \
# 0    2021-22  Regular%20Season     203954     1            Joel Embiid
# 1    2021-22  Regular%20Season     203507     2  Giannis Antetokounmpo
# 2    2021-22  Regular%20Season    1629029     3            Luka Doncic
# 3    2021-22  Regular%20Season    1629027     4             Trae Young
# 4    2021-22  Regular%20Season     201942     5          DeMar DeRozan
# ..       ...               ...        ...   ...                    ...
# 223  2021-22  Regular%20Season    1628373   224        Frank Ntilikina
# 224  2021-22  Regular%20Season    1629308   225  Juan Toscano-Anderson
# 225  2021-22  Regular%20Season    1629162   226      Jordan McLaughlin
# 226  2021-22  Regular%20Season    1630235   227          Trent Forrest
# 227  2021-22  Regular%20Season    1630625   228          Dalano Banton
#
#         TEAM_ID TEAM  GP   MIN   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  \
# 0    1610612755  PHI  68  33.8   9.8  19.6   0.499   1.4   3.7    0.371  9.6
# 1    1610612749  MIL  67  32.9  10.3  18.6   0.553   1.1   3.6    0.293  8.3
# 2    1610612742  DAL  65  35.4   9.9  21.6   0.457   3.1   8.8    0.353  5.6
# 3    1610612737  ATL  76  34.9   9.4  20.3   0.460   3.1   8.0    0.382  6.6
# 4    1610612741  CHI  76  36.1  10.2  20.2   0.504   0.7   1.9    0.352  6.8
# ..          ...  ...  ..   ...   ...   ...     ...   ...   ...      ...  ...
# 223  1610612742  DAL  58  11.8   1.5   3.8   0.399   0.7   1.9    0.342  0.4
# 224  1610612744  GSW  73  13.6   1.6   3.2   0.489   0.4   1.2    0.322  0.5
# 225  1610612750  MIN  62  14.5   1.4   3.2   0.440   0.4   1.4    0.318  0.5
# 226  1610612762  UTA  60  12.8   1.3   2.6   0.490   0.1   0.5    0.185  0.6
# 227  1610612761  TOR  64  10.9   1.3   3.2   0.411   0.2   0.8    0.255  0.4
#
#       FTA  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV   PTS   EFF
# 0    11.8   0.814   2.1   9.6  11.7  4.2  1.1  1.5  3.1  30.6  33.9
# 1    11.4   0.722   2.0   9.6  11.6  5.8  1.1  1.4  3.3  29.9  35.0
# 2     7.5   0.744   0.9   8.3   9.1  8.7  1.2  0.6  4.5  28.4  29.8
# 3     7.3   0.904   0.7   3.1   3.7  9.7  0.9  0.1  4.0  28.4  27.2
# 4     7.8   0.877   0.7   4.4   5.2  4.9  0.9  0.3  2.4  27.9  25.8
# ..    ...     ...   ...   ...   ...  ...  ...  ...  ...   ...   ...
# 223   0.4   0.960   0.2   1.2   1.4  1.2  0.5  0.1  0.5   4.1   4.4
# 224   1.0   0.571   0.4   2.0   2.4  1.7  0.7  0.2  0.9   4.1   6.1
# 225   0.6   0.750   0.4   1.2   1.5  2.9  0.9  0.2  0.6   3.8   6.7
# 226   0.8   0.792   0.4   1.3   1.7  1.8  0.5  0.1  0.8   3.3   5.0
# 227   0.7   0.591   0.6   1.3   1.9  1.5  0.4  0.2  0.8   3.2   4.3
#
# [228 rows x 27 columns]

# %%
del temp_df1, temp_df2, temp_df3

# %%
df_cols = ['Year', 'Season_type'] + table_headers

# %%
pd.DataFrame(columns=df_cols)
# Out:
# Empty DataFrame
# Columns: [Year, Season_type, PLAYER_ID, RANK, PLAYER, TEAM_ID, TEAM, GP, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PTS, EFF]
# Index: []

# %%
headers = {
    'Accept': '*/*',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'Connection': 'keep-alive',
    'DNT': '1',
    'Host': 'stats.nba.com',
    'If-Modified-Since': 'Mon, 23 Jan 2023 18:29:46 GMT',
    'Origin': 'https://www.nba.com',
    'Referer': 'https://www.nba.com/',
    'sec-ch-ua': '"Not_A Brand";v="99", "Google Chrome";v="109", "Chromium";v="109"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': "Windows",
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-site',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}

# %%
df = pd.DataFrame(columns=df_cols)
season_types = ['Regular%20Season', 'Playoffs']
years = ['2021-22']

begin_loop = time.time()

for y in years:
    for s in season_types:
        api_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season='+y+'&SeasonType='+s+'&StatCategory=PTS'
        r = requests.get(url=api_url).json()
        temp_df1 = pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
        temp_df2 = pd.DataFrame({'Year':[y for i in range(len(temp_df1))],
                                 'Season_type':[s for i in range(len(temp_df1))]})
        temp_df3 = pd.concat([temp_df2,temp_df1], axis=1)
        df = pd.concat([df, temp_df3], axis=0)
        print(f'Finished scraping data for the {y} {s}.')
        lag = np.random.uniform(low=5,high=20)
        print(f'...waiting {round(lag,1)} seconds')
        time.sleep(lag)
              
print(f'Process completed! Total run-time: {round((time.time()-begin_loop)-60/2)}')
df.to_excel('nba_stats.xlsx',index=False)
# Out:
# Finished scraping data for the 2021-22 Regular%20Season.
# ...waiting 14.8 seconds
# Finished scraping data for the 2021-22 Playoffs.
# ...waiting 5.7 seconds
# Process completed! Total run-time: -9

# %%
df
# Out:
#         Year       Season_type PLAYER_ID RANK                   PLAYER  \
# 0    2021-22  Regular%20Season    203954    1              Joel Embiid
# 1    2021-22  Regular%20Season    203507    2    Giannis Antetokounmpo
# 2    2021-22  Regular%20Season   1629029    3              Luka Doncic
# 3    2021-22  Regular%20Season   1629027    4               Trae Young
# 4    2021-22  Regular%20Season    201942    5            DeMar DeRozan
# ..       ...               ...       ...  ...                      ...
# 143  2021-22          Playoffs   1629750  144            Javonte Green
# 144  2021-22          Playoffs   1627789  145  Timothe Luwawu-Cabarrot
# 145  2021-22          Playoffs    202684  146         Tristan Thompson
# 146  2021-22          Playoffs   1630267  147         Facundo Campazzo
# 147  2021-22          Playoffs   1630201  147            Malachi Flynn
#
#         TEAM_ID TEAM  GP   MIN   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  \
# 0    1610612755  PHI  68  33.8   9.8  19.6   0.499   1.4   3.7    0.371  9.6
# 1    1610612749  MIL  67  32.9  10.3  18.6   0.553   1.1   3.6    0.293  8.3
# 2    1610612742  DAL  65  35.4   9.9  21.6   0.457   3.1   8.8    0.353  5.6
# 3    1610612737  ATL  76  34.9   9.4  20.3   0.460   3.1   8.0    0.382  6.6
# 4    1610612741  CHI  76  36.1  10.2  20.2   0.504   0.7   1.9    0.352  6.8
# ..          ...  ...  ..   ...   ...   ...     ...   ...   ...      ...  ...
# 143  1610612741  CHI   5  14.4   0.6   3.4   0.176   0.0   1.2    0.000  0.2
# 144  1610612737  ATL   4   5.5   0.5   1.0   0.500   0.3   0.8    0.333  0.0
# 145  1610612741  CHI   5   7.6   0.4   1.0   0.400   0.0   0.0    0.000  0.0
# 146  1610612743  DEN   4   3.3   0.0   0.5   0.000   0.0   0.5    0.000  0.0
# 147  1610612761  TOR   6   6.0   0.0   1.2   0.000   0.0   0.5    0.000  0.0
#
#       FTA  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV   PTS   EFF
# 0    11.8   0.814   2.1   9.6  11.7  4.2  1.1  1.5  3.1  30.6  33.9
# 1    11.4   0.722   2.0   9.6  11.6  5.8  1.1  1.4  3.3  29.9  35.0
# 2     7.5   0.744   0.9   8.3   9.1  8.7  1.2  0.6  4.5  28.4  29.8
# 3     7.3   0.904   0.7   3.1   3.7  9.7  0.9  0.1  4.0  28.4  27.2
# 4     7.8   0.877   0.7   4.4   5.2  4.9  0.9  0.3  2.4  27.9  25.8
# ..    ...     ...   ...   ...   ...  ...  ...  ...  ...   ...   ...
# 143   0.4   0.500   1.6   1.4   3.0  0.4  1.8  0.0  0.8   1.4   2.8
# 144   0.0   0.000   0.0   0.8   0.8  0.5  0.0  0.0  0.3   1.3   1.8
# 145   0.0   0.000   0.4   1.2   1.6  0.4  0.2  0.0  1.0   0.8   1.4
# 146   0.0   0.000   0.0   0.8   0.8  0.5  0.0  0.0  0.5   0.0   0.3
# 147   0.0   0.000   0.3   0.2   0.5  0.5  0.2  0.0  0.2   0.0  -0.2
#
# [376 rows x 27 columns]
